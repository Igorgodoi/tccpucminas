# %% [markdown]
# <a href="https://colab.research.google.com/github/Igorgodoi/tccpucminas/blob/master/TCCMINAS_AnaliseExploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Autor: Igor Reis de Godoi
# TCC PUCMINAS 2020 - Predição da duração de uma audiência trabalhista
# Terceira parte - Analise Exploratoria dos Dados

# %%
# Importando bibliotecas
# !pip install -U pandas-profiling
from pandas_profiling import ProfileReport
from google.colab import drive
# %matplotlib inline
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# Importando o dataset audiencias processada
drive.mount('/content/drive')
df_audiencia = pd.read_csv(''/content/drive/My Drive/Colab Notebooks/datasets/dataset_audiencias.csv'',sep=';')
df_audiencia.head()

# %%
# Análise exploratória Audiências
profile_audiencia = ProfileReport(df_audiencia, title='Audiência',html={'style':{'full_width':True}})
profile_audiencia.to_notebook_iframe()
